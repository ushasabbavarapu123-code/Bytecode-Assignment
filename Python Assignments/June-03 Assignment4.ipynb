# %% [markdown]
# # 1.Print all elements of a list

# %%
ls=[10,30,18,20,60]
print(ls)
# Out:
# [10, 30, 18, 20, 60]

# %% [markdown]
# # 2.Print all fruits

# %%
ls=["Grapes","Orange","Kiwi","Mango"]
print(ls)
# Out:
# ['Grapes', 'Orange', 'Kiwi', 'Mango']

# %% [markdown]
# # 3.Print numbers from 1 to 5

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 4.Find the sum of all numbers (list)

# %%
ls=[1,2,3,4,8,10,30,40]
sum=0
for i in ls:
  sum=sum+i
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 18
# 28
# 58
# 98

# %% [markdown]
# # 5.Count the number of elements (list)

# %%
ls=[10,20,30,79,60,50]
for i in ls:
  length=len(ls)
print(length)
# Out:
# 6

# %% [markdown]
# # 6.Find the average (marks = [70, 80, 90, 60])

# %%
from re import A
marks=[70,30,50,20,45,36]
total=0
for i in marks:
  total=total+i
  avg=total/len(marks)
print(total)
print(avg)
# Out:
# 251
# 41.833333333333336

# %% [markdown]
# #7.Print even numbers

# %%
ls=[1,3,4,6,10,20,35,47]
for num in ls:
  print(num)
for num in ls:
  if num%2==0:
     print("The even number",num)
# Out:
# 1
# 3
# 4
# 6
# 10
# 20
# 35
# 47
# The even number 4
# The even number 6
# The even number 10
# The even number 20

# %% [markdown]
# #8.Print odd numbers

# %%
ls=[10,22,34,23,46,57,21,13,17]
for num in ls:
  print(num)
for num in ls:
  if num%2!=0:
     print("The odd number",num)
# Out:
# 10
# 22
# 34
# 23
# 46
# 57
# 21
# 13
# 17
# The odd number 23
# The odd number 57
# The odd number 21
# The odd number 13
# The odd number 17

# %% [markdown]
# #9.Count positive numbers

# %%
ls=[5,-6,9,10,-30,-80]
for num in ls:
  if num>0:
    print("The Number Positive is",num)
# Out:
# The Number Positive is 5
# The Number Positive is 9
# The Number Positive is 10

# %% [markdown]
# #10.Print each character

# %%
ls="Data Analytics"
for i in ls:
  print(i)
# Out:
# D
# a
# t
# a
#
# A
# n
# a
# l
# y
# t
# i
# c
# s

# %% [markdown]
# #11.Count vowels

# %%
ls="hello world"
vowels="aeiouAEIOU"
count=0
for i in ls:
  if i in vowels:
    count=count+1
print(count)
# Out:
# 3

# %% [markdown]
# #12.Count Uppercase Letters

# %%
ls="HELLO WORLD"
count=0
for i in ls:
  if i.isupper():
    count=count+1
print(count)
# Out:
# 10

# %% [markdown]
# #13.Find the largest Number

# %%
ls=[1,2,3,4,56,76,89]
for i in ls:
  largest=max(ls)
print(largest)
# Out:
# 89

# %% [markdown]
# #14.Find The Smallest Number

# %%
ls=[1,2,3,4,56,76,89]
for i in ls:
  smallest=min(ls)
print(smallest)
# Out:
# 1

# %% [markdown]
# #15.Print index and value

# %%
ls =[1,2,4,20,50,80,100]
for index,value in enumerate(ls):
  print(index,value)
# Out:
# 0 1
# 1 2
# 2 4
# 3 20
# 4 50
# 5 80
# 6 100

# %% [markdown]
# #16.Print Elements at even Position

# %%
ls1 = [11, 14, 40, 20, 60]

for num in range(len(ls1)):
    if num % 2 == 0:
        print(ls1[num])
# Out:
# 11
# 40
# 60

# %% [markdown]
# #17.Print all keys

# %%
dict={"name":"usha","age":21,"city":"vizag"}
for i in dict.keys():
  print(i)
# Out:
# name
# age
# city

# %% [markdown]
# #18.Print all the values

# %%
dict={"name":"usha","age":21,"city":"vizag"}
for i in dict.values():
  print(i)
# Out:
# usha
# 21
# vizag

# %% [markdown]
# #19.Print the items

# %%
dict={"name":"usha","age":21,"city":"vizag"}
for i in dict.items():
  print(i)
# Out:
# ('name', 'usha')
# ('age', 21)
# ('city', 'vizag')

# %% [markdown]
# #20.Calculate total sales

# %%
sales={"shirts":100,"jeans":3000,"tops":200,"shorts":400}
total_sales=0
for i in sales.values():
  total_sales=total_sales+i
print(total_sales)
# Out:
# 3700

# %% [markdown]
# #21.Find highest sales value

# %%
sales={"shirts":100,"jeans":3000,"tops":200,"shorts":400}
total_sales=0
for i in sales.values():
   largest=max(sales.values())
print(largest)
# Out:
# 3000

# %% [markdown]
# #22.Count customers with purchases above 1000

# %%
sales={"usha":100,
       "pavi":2000,
       "indumathi":3000,
       "likhii":400}
count=0
for i in sales.values():
  if i>1000:
    count=count+1
print(count)
# Out:
# 2

# %% [markdown]
# #23.Print products with price greater than 500

# %%
sales={"serum":550,
       "sunscreen":800,
       "lipstick":200,
       "moisturizer":400}
for sales,sale in sales.items():
  if sale>500:
    print(sales)
# Out:
# serum
# sunscreen
