# %% [markdown]
# 1. Employee Code Analysis : emp_code = "EMP20250601"
# Extract:
# Employee ID = EMP
# Year = 2025
# Month = 06
# Day = 01

# %%
emp_code="EMP20250601"
employee_id=emp_code[:3]
year=emp_code[3:7]
month=emp_code[7:9]
day=emp_code[9:11]

print("Employee_id =",employee_id)
print("Year=",year)
print("Month=",month)
print("Day=",day)
# Out:
# Employee_id = EMP
# Year= 2025
# Month= 06
# Day= 01

# %% [markdown]
# 2. Customer Mobile Masking : mobile = "9876543210"
# Expected Output:
# ******3210

# %%
mobile="9876543210"
masked_mobile= "*"*6 + mobile[-4:]
print(masked_mobile)
# Out:
# ******3210

# %% [markdown]
# 3. Reverse Alternate Characters
# text = "DataAnalytics"

# %%
name="DataAnalytics"
print(name[::-1])
# Out:
# scitylanAataD

# %% [markdown]
# 4. Product Code Analysis : product = "PRD-4587-HYD"
# Extract:
# •	Product Type
# •	Product Number
# •	Location

# %%
product="PRD-4587-HYD"
product_type=product[:3]
product_number=product[4:8]
location=product[9:12]

print("Product_Type=",product_type)
print("Product_Number=",product_number)
print("Location=",location)
# Out:
# Product_Type= PRD
# Product_Number= 4587
# Location= HYD

# %% [markdown]
# 5. Customer Analysis Using Sets
# january_customers = {101,102,103,104,105}
# february_customers = {103,104,105,106,107}
# Find:
# •	Repeat customers
# •	New customers in February
# •	Customers who purchased only in January

# %%
s1:january_customers = {101,102,103,104,105}
s2:february_customers = {103,104,105,106,107}
print(s1.intersection(s2))
print(s1.difference(s2))
print(s1.symmetric_difference(s2))
# Out:
# {104, 105, 103}
# {101, 102}
# {101, 102, 106, 107}

# %% [markdown]
# 6. Marketing Campaign Analysis
# Campaign A: A = {1001,1002,1003,1004,1005}
# Campaign B: B = {1004,1005,1006,1007}
# Find:
# •	Customers reached by both campaigns
# •	Customers reached by either campaign
# •	Customers reached by exactly one campaign

# %%
S1:A = {1001,1002,1003,1004,1005}
S2:B = {1004,1005,1006,1007}
print(S1.union(S2))
print(s1.symmetric_difference(s2))
print(s1.difference(s2))
# Out:
# {1001, 1002, 1003, 1004, 1005, 1006, 1007}
# {101, 102, 106, 107}
# {101, 102}

# %% [markdown]
# 7. Data Cleaning : sales = [100,200,100,300,200,400,500,400]
# Tasks:
# •	Remove duplicates using sets.
# •	Find count of unique sales values.
# •	Convert result back to list.

# %%
sales = [100,200,100,300,200,400,500,400]
unique_sales=set(sales)
count_unique=len(unique_sales)
unique_sales_list=list(unique_sales)
print("Unique_sales:",unique_sales)
print("Count of Unique_sales:",count_unique)
print("list after removing duplicates:",unique_sales_list)
# Out:
# Unique_sales: {100, 200, 300, 400, 500}
# Count of Unique_sales: 5
# list after removing duplicates: [100, 200, 300, 400, 500]

# %% [markdown]
# 8. Website Visitors
# - day1 = {101,102,103,104,105}
# - day2 = {103,104,105,106,107}
# - day3 = {104,105,108}
# #Find:
# •	Visitors who came all 3 days
# •	Visitors who came at least once
# •	Visitors who visited only Day 1

# %%
d1:1 = {101,102,103,104,105}
d2:2= {103,104,105,106,107}
d3:3= {104,105,108}
print(d1.intersection(d2))
print(d1.symmetric_difference(d2))
print(d1.difference(d2))
# Out:
# {104, 105, 103}
# {101, 102, 106, 107}
# {101, 102}

# %% [markdown]
# 9. Sales Transaction ID
# txn = "TXN2025HYD4589"
# Extract:
# •	TXN
# •	Year
# •	City
# •	Transaction Number

# %%
Transaction_ID= "TXN2025HYD4589"
txn=Transaction_ID[:3]
year=Transaction_ID[3:7]
city=Transaction_ID[7:10]
transaction_number=Transaction_ID[10:14]

print("TXN=",txn)
print("Year=",year)
print("City=",city)
print("Transaction_Number=",transaction_number)
# Out:
# TXN= TXN
# Year= 2025
# City= HYD
# Transaction_Number= 4589

# %% [markdown]
# 10.Duplicate Customer IDs : customers = [101,102,103,101,104,105,102,106]
# #Tasks:
# - Find unique customers
# -	Count duplicates removed
# - Find total unique customers

# %%
customers = [101,102,103,101,104,105,102,106]
unique_customers=set(customers)
count_unique=len(unique_customers)
unique_customers_list=list(unique_customers)
print("Unique_Customers:",unique_customers)
print("Count of Unique_customers=:",count_unique)
print("Total unique customers:",unique_customers_list)
# Out:
# Unique_Customers: {101, 102, 103, 104, 105, 106}
# Count of Unique_customers=: 6
# Total unique customers: [101, 102, 103, 104, 105, 106]

# %% [markdown]
# 11. SKU Analysis
# - sku = "MOB-SAM-128-BLK"
# #Extract:
# - Category
# - Brand
# - Storage
# - Color

# %%
sku = "MOB-SAM-128-BLK"
category=sku[:3]
brand=sku[4:7]
storage=sku[8:11]
color=sku[12:15]

print("Catgory=",category)
print("Brand=",brand)
print("Storage=",storage)
print("Color=",color)
# Out:
# Catgory= MOB
# Brand= SAM
# Storage= 128
# Color= BLK

# %% [markdown]
# 12. Common Products Sold
# - store1 = {"Laptop","Mouse","Keyboard","Monitor"}
# - store2 = {"Mouse","Monitor","Printer","Scanner"}
# #Find:
# - Common products
# - Exclusive products for each store
# - Total unique products

# %%
s1= {"Laptop","Mouse","Keyboard","Monitor"}
s2= {"Mouse","Monitor","Printer","Scanner"}
print(s1.intersection(s2))
print(s1.difference(s2))
print(s1.union(s2))
# Out:
# {'Mouse', 'Monitor'}
# {'Laptop', 'Keyboard'}
# {'Mouse', 'Printer', 'Keyboard', 'Scanner', 'Laptop', 'Monitor'}

# %% [markdown]
# 13. Mini Case Study
# An e-commerce company ran campaigns in 3 months:
#
# - jan = {101,102,103,104,105}
# - feb = {103,104,105,106,107}
# - mar = {105,106,107,108,109}
#
# - Total unique customers targeted.
# - Customers targeted in all months.
# - Customers targeted only once.
# - Customers targeted in January and February but not March.
# - Customers targeted in February and March but not January.

# %%
a=jan = {101,102,103,104,105}

b=feb = {103,104,105,106,107}

c=mar = {105,106,107,108,109}
print(a.union(b).union(c))
print(a.intersection(b).intersection(c))
print(a.difference(b).difference(c))
print(a.intersection(b).difference(c))
print(b.intersection(c).difference(a))
# Out:
# {101, 102, 103, 104, 105, 106, 107, 108, 109}
# {105}
# {101, 102}
# {104, 103}
# {106, 107}
